# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel("avocado.xls")
df
# Out:
#             Date  AveragePrice  Total Volume    A4046      A4225   A4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %% [markdown]
# The given data set consists of 18249 Rows and 13 Columns

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# A4046           0
# A4225           0
# A4770           0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.loc[df["Date"]==" "]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, A4046, A4225, A4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %%
df.loc[df["AveragePrice"]==" "]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, A4046, A4225, A4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %%
df.loc[df["Total Volume"]==" "]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, A4046, A4225, A4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %%
df.loc[df["Total Bags"]==" "]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, A4046, A4225, A4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %%
df.loc[df["Small Bags"]==" "]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, A4046, A4225, A4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %%
df.loc[df["Large Bags"]==" "]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, A4046, A4225, A4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %%
df.loc[df["XLarge Bags"]==" "]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, A4046, A4225, A4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %%
df.loc[df["type"]==" "]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, A4046, A4225, A4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %%
df.loc[df["year"]==" "]
# Out:
# Empty DataFrame
# Columns: [Date, AveragePrice, Total Volume, A4046, A4225, A4770, Total Bags, Small Bags, Large Bags, XLarge Bags, type, year, region]
# Index: []

# %% [markdown]
# There is null value present in the given dataset

# %%
 df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', 'A4046', 'A4225', 'A4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# A4046                  float64
# A4225                  float64
# A4770                  float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %% [markdown]
# The given data set consist of Float,Integer and Object type

# %%
Cat_Columns=["Date","type","region"]

for i in df[Cat_Columns]:
        print(str(i))
        print(df[i].value_counts())
        print("\n")
# Out:
# Date
# 2015-05-24    108
# 2015-09-13    108
# 2016-08-07    108
# 2015-03-08    108
# 2017-07-02    108
#              ...
# 2015-03-22    108
# 2017-07-16    108
# 2017-06-25    107
# 2015-12-06    107
# 2017-06-18    107
# Name: Date, Length: 169, dtype: int64
#
#
# type
# conventional    9126
# organic         9123
# Name: type, dtype: int64
#
#
# region
# BaltimoreWashington    338
# Jacksonville           338
# StLouis                338
# Boise                  338
# MiamiFtLauderdale      338
# Pittsburgh             338
# HarrisburgScranton     338
# RichmondNorfolk        338
# Tampa                  338
# Northeast              338
# Sacramento             338
# BuffaloRochester       338
# Philadelphia           338
# Albany                 338
# NorthernNewEngland     338
# Roanoke                338
# Charlotte              338
# HartfordSpringfield    338
# NewOrleansMobile       338
# Detroit                338
# RaleighGreensboro      338
# ...

# %%
num_Columns=['AveragePrice', 'Total Volume','Total Bags','Small Bags','Large Bags', 'XLarge Bags','year']

for i in df[num_Columns]:
        print(str(i))
        print(df[i].value_counts())
        print("\n")
# Out:
# AveragePrice
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.05      1
# 3.03      1
# 2.91      1
# 0.48      1
# 2.96      1
# Name: AveragePrice, Length: 259, dtype: int64
#
#
# Total Volume
# 3713.49      2
# 3529.44      2
# 2038.99      2
# 569349.05    2
# 4103.97      2
#             ..
# 238229.99    1
# 344613.01    1
# 322940.72    1
# 2943.85      1
# 10187.56     1
# Name: Total Volume, Length: 18237, dtype: int64
#
#
# Total Bags
# 0.00          15
# 300.00         5
# 990.00         5
# 916.67         4
# 266.67         4
#               ..
# 155484.69      1
# 224912.37      1
# 613.16         1
# 93342.82       1
# 1040085.28     1
# Name: Total Bags, Length: 18097, dtype: int64
#
#
# Small Bags
# 0.00         159
# 203.33        11
# 533.33        10
# 223.33        10
# 103.33         8
#             ...
# 27683.11       1
# 1995.38        1
# 269775.24      1
# 52556.00       1
# 27837.68       1
# ...

# %% [markdown]
# In this were we can able to find the Unique value in Categorical dataset

# %%
columns=['region',"type","year"]

for  i in df[columns]:
    plt.figure()
    sb.countplot(df[i])

# %% [markdown]
# All the data's are equally distiputed in all the columns and only the 2018 in year columns has less count

# %% [markdown]
# Converting categorical into Numerical

# %%
month=df["Date"].dt.month

# %%
day=df["Date"].dt.day

# %%
year=df["Date"].dt.year

# %%
df["month"]=month

# %%
df["day"]=day

# %%
df=df.drop("Date",axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df["type"]=le.fit_transform(df["type"])
df["region"]=le.fit_transform(df["region"])

# %%
df["day"].dtypes
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#    AveragePrice  Total Volume    A4046      A4225   A4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  month  day
# 0     8603.62       93.25          0.0     0  2015       0     12   27
# 1     9408.07       97.49          0.0     0  2015       0     12   20
# 2     8042.21      103.14          0.0     0  2015       0     12   13
# 3     5677.40      133.76          0.0     0  2015       0     12    6
# 4     5986.26      197.69          0.0     0  2015       0     11   29

# %% [markdown]
# Univariate analysis

# %%
columns=['AveragePrice',        'Total Volume',                  'A4046',
                        'A4225',                  'A4770',          'Total Bags',
                'Small Bags',          'Large Bags',         'XLarge Bags',
                      'type',  ]

for  i in df[columns]:
    plt.figure()
    sb.boxplot(df[i])

# %% [markdown]
# There are outliers present in 'AveragePrice', 'Total Volume', 4046, 4225, 4770, 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags',

# %%
columns=['AveragePrice',        'Total Volume',                  'A4046',
                        'A4225',                  'A4770',          'Total Bags',
                'Small Bags',          'Large Bags',         'XLarge Bags',
                      'type',  ]

for  i in df[columns]:
    plt.figure()
    sb.distplot(df[i])

# %%
pd.set_option("display.max_rows", None)

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# A4046            8.648220
# A4225            8.942466
# A4770           10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# month            0.106617
# day              0.014310
# dtype: float64

# %%
sb.pairplot(df)

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume         A4046         A4225         A4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          type  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507      0.499918
# ...

# %%
plt.figure(figsize=(22,15))
sb.heatmap(df.describe())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume     A4046     A4225     A4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# A4046            -0.208317      0.977863  1.000000  0.926110  0.833389
# A4225            -0.172928      0.974181  0.926110  1.000000  0.887855
# A4770            -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
# ...

# %%
plt.figure(figsize=(22,15))
sb.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="purple",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()["AveragePrice"].sort_values(ascending=False).drop(["AveragePrice"]).plot(kind="bar",color="c")
plt.xlabel("feature",fontsize=14)
plt.ylabel("column with target name",fontsize=14)
plt.title("correlation",fontsize=18)
plt.show()

# %%
columns=[        'Total Volume',                  'A4046',
                        'A4225',                  'A4770',          'Total Bags',
                'Small Bags',          'Large Bags',         'XLarge Bags',
                      'type',  ]

for  i in df[columns]:
    plt.figure()
    k=sb.scatterplot(df[i],df["AveragePrice"],alpha=0.5,c=(0,1,1),hue=df['AveragePrice'])

# %%
df.head()
# Out:
#    AveragePrice  Total Volume    A4046      A4225   A4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  month  day
# 0     8603.62       93.25          0.0     0  2015       0     12   27
# 1     9408.07       97.49          0.0     0  2015       0     12   20
# 2     8042.21      103.14          0.0     0  2015       0     12   13
# 3     5677.40      133.76          0.0     0  2015       0     12    6
# 4     5986.26      197.69          0.0     0  2015       0     11   29

# %%
df=df.astype(float)

# %% [markdown]
# This plot shows the dataset have average Correlation with target variable

# %% [markdown]
# To reduce the Outlier We can use Standard scaler

# %%
x=df.drop("AveragePrice",axis=1)
y=df["AveragePrice"]

# %% [markdown]
# We can see that datas are positively skewed except density

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler(x)

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings("ignore")

# %%
lr=LinearRegression()
rfr=RandomForestRegressor()
dtr=DecisionTreeRegressor()
knr=KNeighborsRegressor()
svr=()

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At the random state {i}, the Training accuracy is :- {r2_score(y_train,pred_train)}")
    print(f"At the random state {i}, the Testing accuracy is :- {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At the random state 0, the Training accuracy is :- 0.43679101988662183
# At the random state 0, the Testing accuracy is :- 0.44757184183107956
#
#
# At the random state 1, the Training accuracy is :- 0.4381659780300525
# At the random state 1, the Testing accuracy is :- 0.44273661259393915
#
#
# At the random state 2, the Training accuracy is :- 0.4431058894658747
# At the random state 2, the Testing accuracy is :- 0.42239762442469453
#
#
# At the random state 3, the Training accuracy is :- 0.4398672783100327
# At the random state 3, the Testing accuracy is :- 0.4357412012596762
#
#
# At the random state 4, the Training accuracy is :- 0.4423619715664874
# At the random state 4, the Testing accuracy is :- 0.425749173322824
#
#
# At the random state 5, the Training accuracy is :- 0.4386316372139576
# At the random state 5, the Testing accuracy is :- 0.43983161650050195
#
#
# At the random state 6, the Training accuracy is :- 0.4379459898443123
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=12)

# %%
lr.fit(x_train,y_train)
pred_test=lr.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.4494054083480701

# %%
train_accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)

for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At the cross fold{j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy for the testing is {test_accuracy}")
    print("\n")
# Out:
# At the cross fold2 the cv score is -5416.937043106775 and accuracy score for training is -0.45648057596650515 and accuracy for the testing is 0.4494054083480701
#
#
# At the cross fold3 the cv score is -13.250639387943261 and accuracy score for training is -0.45648057596650515 and accuracy for the testing is 0.4494054083480701
#
#
# At the cross fold4 the cv score is -12.353807329211334 and accuracy score for training is -0.45648057596650515 and accuracy for the testing is 0.4494054083480701
#
#
# At the cross fold5 the cv score is -10.886791716837083 and accuracy score for training is -0.45648057596650515 and accuracy for the testing is 0.4494054083480701
#
#
# At the cross fold6 the cv score is -1.0152112835994613 and accuracy score for training is -0.45648057596650515 and accuracy for the testing is 0.4494054083480701
#
#
# ...

# %% [markdown]
# Hyper parameter tuning

# %%
parameters={"criterion":["mse","mae"],"max_features":["auto","sqrt","log2"]}
rfr=RandomForestRegressor()
clf=GridSearchCV(rfr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rfr=RandomForestRegressor(criterion="mse",max_features="auto")
rfr.fit(x_train,y_train)
rfr.score(x_train,y_train)
pred_decision=rfr.predict(x_test)
pred_test_rfr=rfr.predict(x_test)
rfs=r2_score(y_test,pred_decision)
print("R2 Score",rfs*100)

rfscore=cross_val_score(rfr,x,y,cv=5)
rfc=rfscore.mean()  
print("Cross Val Score",rfc*100)
# Out:
# R2 Score 89.27878264348418
# Cross Val Score 22.22085766052457

# %%
cv_score=cross_val_score(rfr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.2113957688020705

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test_rfr,color="r")
plt.plot(y_test,y_test,color="b")
plt.xlabel("Average prices",fontsize=14)
plt.ylabel("predicted prices", fontsize=14)
plt.title("Random Forest Regressor",fontsize=18)
plt.show()

# %%
parameters={"splitter":["best","random"],"max_features":["auto","log2","sqrt",None]}
clf=GridSearchCV(dtr,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'max_features': None, 'splitter': 'best'}

# %%
dtr=DecisionTreeRegressor(splitter="best", max_features="auto")
dtr.fit(x_train,y_train)
dtr.score(x_train,y_train)
pred_decision=dt ,r.predict(x_test)
pred_test_dtr=dtr.predict(x_test)
dtr_=r2_score(y_test,pred_decision)
print("R2 Score",rfs*100)

rfscore=cross_val_score(dtr,x,y,cv=10)
rfr=rfscore.mean()
# Out:
# R2 Score 89.27878264348418

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test_dtr,color="r")
plt.plot(y_test,y_test,color="b")
plt.xlabel("Average prices",fontsize=14)
plt.ylabel("predicted prices", fontsize=14)
plt.title("Decision tree Regressor",fontsize=18)
plt.show()

# %% [markdown]
# Saving a model (Random Forest Regressor)
# Performed the samed= data with removing removing skewness and without removing skewnessbut the dataset without removing skewness worked better

# %%
import pickle
filename="Avacado.pkl"
pickle.dump(rfr,open(filename,"wb"))

# %%
+
